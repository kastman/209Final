# %%
import glob
import os
import pandas as pd
import re

# %%
import csv
years = ['2007', '2008', '2009','2010', '2011', '2012', '2013', '2014', '2015', '2016']

dict_list={year:{} for year in years}
with open('data/derived/colnames_final.csv', 'r') as csvfile:
    spamwriter = csv.reader(csvfile)
    for row in spamwriter:
        final_name=row[-1]
        for year,colname in zip(years, row[:-1]):
            dict_list[year][colname]=final_name

# %%
from functools import reduce

dem_files_byYear = []

merge_columns = ['MSA', 'year','MSA_type','Id', 'Id2','Geography']

raw_tables_path = 'data/raw/ACS_2007_2016'

# for each year folder, concatenate across the 4 data profile files, 
# save one resulting df per year in the dem_files_byYear list

for year in years:
    # * allows for gziped csv's 
    dem_files = glob.glob(os.path.join(raw_tables_path, year, 'ACS_*_1YR_*with_ann.csv*'))  
    year_pat = re.compile(r'(\d{2})')
    dem_df_list = []
    for fname in dem_files:
        dem_yr_df = pd.read_csv(fname, skiprows=1, header=0)
        dem_yr_df['year'] = int(year)
        dem_yr_df[['MSA', 'MSA_type']] = dem_yr_df['Geography'].str.extract(r'(^.*)\ (M.*)$')
        #drop any column that isn't a percent
        bad_col_names = [x for x in dem_yr_df.columns.values if 'Percent;' not in x and x not in merge_columns]
        dem_yr_df = dem_yr_df[dem_yr_df.columns.drop(bad_col_names)]
        #drop any margin of error columns
        dem_yr_df = dem_yr_df[dem_yr_df.columns.drop(list(dem_yr_df.filter(regex='Margin of Error')))]
        #rename all columns to a standard naming format
        dem_yr_df.rename_axis(dict_list[year], axis=1, inplace=True)
        
        dem_df_list.append(dem_yr_df)
    dem_year = reduce(lambda x, y: pd.merge(x, y, on = merge_columns), dem_df_list)
    #dem_year.to_csv((folder + 'dataprof.csv'), index=False)
    dem_files_byYear.append(dem_year)
dem_year.shape
# Out:
# C:\Users\Will\Anaconda3\lib\site-packages\ipykernel\__main__.py:20: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# (511, 522)

# %%
will = dem_files_byYear[0].copy()
will = will.append(dem_files_byYear[1])
will = will.append(dem_files_byYear[2])
will = will.append(dem_files_byYear[3])
will = will.append(dem_files_byYear[4])
will = will.append(dem_files_byYear[5])
will = will.append(dem_files_byYear[6])
will.shape
# Out:
# (3579, 524)

# %%
#concatenate each resulting year file so we have one final ACS data file
dem_df = will

print(dem_df.shape)
dem_df.head(10)
# Out:
# (3579, 524)
#                                 Geography              Id    Id2  \
# 0                 Aberdeen, WA Micro Area  3100000US10140  10140
# 1                  Abilene, TX Metro Area  3100000US10180  10180
# 2                   Adrian, MI Micro Area  3100000US10300  10300
# 3                    Akron, OH Metro Area  3100000US10420  10420
# 4                   Albany, GA Metro Area  3100000US10500  10500
# 5           Albany-Lebanon, OR Micro Area  3100000US10540  10540
# 6  Albany-Schenectady-Troy, NY Metro Area  3100000US10580  10580
# 7              Albertville, AL Micro Area  3100000US10700  10700
# 8              Albuquerque, NM Metro Area  3100000US10740  10740
# 9               Alexandria, LA Metro Area  3100000US10780  10780
#
#                            MSA    MSA_type  \
# 0                 Aberdeen, WA  Micro Area
# 1                  Abilene, TX  Metro Area
# 2                   Adrian, MI  Micro Area
# 3                    Akron, OH  Metro Area
# 4                   Albany, GA  Metro Area
# 5           Albany-Lebanon, OR  Micro Area
# 6  Albany-Schenectady-Troy, NY  Metro Area
# 7              Albertville, AL  Micro Area
# 8              Albuquerque, NM  Metro Area
# 9               Alexandria, LA  Metro Area
#
#   Percent; ANCESTRY - Total population  \
# 0                                  100
# 1                                  100
# 2                                  100
# 3                                  100
# 4                                  100
# 5                                  100
# 6                                  100
# 7                                    N
# 8                                  100
# 9                                  100
#
#   Percent; ANCESTRY - Total population - American  \
# 0                                             3.6
# 1                                             6.9
# 2                                             7.0
# 3                                             5.4
# 4                                             8.3
# 5                                             5.9
# 6                                             6.9
# 7                                               N
# 8                                             3.1
# 9                                            24.4
#
#   Percent; ANCESTRY - Total population - Arab  \
# 0                                         0.0
# 1                                         0.0
# 2                                         0.1
# 3                                         0.7
# 4                                         0.0
# 5                                         0.0
# 6                                         0.4
# 7                                           N
# 8                                         0.3
# 9                                         1.0
#
#   Percent; ANCESTRY - Total population - Czech  \
# 0                                          0.1
# 1                                          0.1
# 2                                          0.3
# 3                                          0.9
# 4                                          0.0
# 5                                          0.5
# 6                                          0.6
# 7                                            N
# 8                                          0.3
# 9                                          0.3
#
#   Percent; ANCESTRY - Total population - Danish  ...   \
# 0                                           1.0  ...
# 1                                           0.2  ...
# 2                                           0.4  ...
# 3                                           0.2  ...
# 4                                           0.2  ...
# 5                                           1.1  ...
# 6                                           0.5  ...
# 7                                             N  ...
# 8                                           0.4  ...
# 9                                           0.1  ...
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1940 to 1949  \
# 0                                               27.4
# 1                                                9.5
# 2                                               25.6
# 3                                               19.4
# 4                                                4.8
# 5                                               12.1
# 6                                               32.3
# 7                                                3.7
# 8                                                3.0
# 9                                                6.4
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1950 to 1959  \
# 0                                                4.8
# 1                                                7.0
# 2                                                5.5
# 3                                                8.0
# 4                                                4.9
# 5                                                5.8
# 6                                                6.0
# 7                                                6.6
# 8                                                4.0
# 9                                                7.7
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1960 to 1969  \
# 0                                                6.7
# 1                                               19.8
# 2                                               12.7
# 3                                               16.5
# 4                                               14.1
# 5                                               10.9
# 6                                               12.4
# 7                                                9.8
# 8                                               10.7
# 9                                               11.8
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1970 to 1979  \
# 0                                               13.3
# 1                                               11.8
# 2                                                8.0
# 3                                               12.4
# 4                                               11.4
# 5                                                9.9
# 6                                               10.0
# 7                                               14.3
# 8                                               10.2
# 9                                               14.6
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1980 to 1989  \
# 0                                               20.1
# 1                                               15.5
# 2                                               14.9
# 3                                               14.4
# 4                                               18.7
# 5                                               26.0
# 6                                               12.9
# 7                                               19.1
# 8                                               20.7
# 9                                               20.7
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1990 to 1999  \
# 0                                               12.7
# 1                                               16.8
# 2                                                9.1
# 3                                                8.6
# 4                                               17.0
# 5                                                9.2
# 6                                               11.0
# 7                                               15.0
# 8                                               17.2
# 9                                               16.4
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 2000 to 2009  \
# 0                                                9.6
# 1                                                9.6
# 2                                               13.8
# 3                                               11.7
# 4                                               17.0
# 5                                               12.6
# 6                                                9.1
# 7                                               18.2
# 8                                               19.0
# 9                                               12.3
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 2010 to 2013  \
# 0                                                3.6
# 1                                                6.5
# 2                                                8.2
# 3                                                6.7
# 4                                               10.0
# 5                                                7.9
# 6                                                4.5
# 7                                                8.6
# 8                                               10.3
# 9                                                7.0
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 2014 or later  \
# 0                                                1.9
# 1                                                3.4
# 2                                                2.2
# 3                                                2.2
# 4                                                2.2
# 5                                                5.7
# 6                                                1.8
# 7                                                4.8
# 8                                                5.0
# 9                                                3.2
#
#    year
# 0  2007
# 1  2007
# 2  2007
# 3  2007
# 4  2007
# 5  2007
# 6  2007
# 7  2007
# 8  2007
# 9  2007
#
# [10 rows x 524 columns]

# %%
print(dem_df.shape)
dem_df.head(10)
# Out:
# (3579, 524)
#                                 Geography              Id    Id2  \
# 0                 Aberdeen, WA Micro Area  3100000US10140  10140
# 1                  Abilene, TX Metro Area  3100000US10180  10180
# 2                   Adrian, MI Micro Area  3100000US10300  10300
# 3                    Akron, OH Metro Area  3100000US10420  10420
# 4                   Albany, GA Metro Area  3100000US10500  10500
# 5           Albany-Lebanon, OR Micro Area  3100000US10540  10540
# 6  Albany-Schenectady-Troy, NY Metro Area  3100000US10580  10580
# 7              Albertville, AL Micro Area  3100000US10700  10700
# 8              Albuquerque, NM Metro Area  3100000US10740  10740
# 9               Alexandria, LA Metro Area  3100000US10780  10780
#
#                            MSA    MSA_type  \
# 0                 Aberdeen, WA  Micro Area
# 1                  Abilene, TX  Metro Area
# 2                   Adrian, MI  Micro Area
# 3                    Akron, OH  Metro Area
# 4                   Albany, GA  Metro Area
# 5           Albany-Lebanon, OR  Micro Area
# 6  Albany-Schenectady-Troy, NY  Metro Area
# 7              Albertville, AL  Micro Area
# 8              Albuquerque, NM  Metro Area
# 9               Alexandria, LA  Metro Area
#
#   Percent; ANCESTRY - Total population  \
# 0                                  100
# 1                                  100
# 2                                  100
# 3                                  100
# 4                                  100
# 5                                  100
# 6                                  100
# 7                                    N
# 8                                  100
# 9                                  100
#
#   Percent; ANCESTRY - Total population - American  \
# 0                                             3.6
# 1                                             6.9
# 2                                             7.0
# 3                                             5.4
# 4                                             8.3
# 5                                             5.9
# 6                                             6.9
# 7                                               N
# 8                                             3.1
# 9                                            24.4
#
#   Percent; ANCESTRY - Total population - Arab  \
# 0                                         0.0
# 1                                         0.0
# 2                                         0.1
# 3                                         0.7
# 4                                         0.0
# 5                                         0.0
# 6                                         0.4
# 7                                           N
# 8                                         0.3
# 9                                         1.0
#
#   Percent; ANCESTRY - Total population - Czech  \
# 0                                          0.1
# 1                                          0.1
# 2                                          0.3
# 3                                          0.9
# 4                                          0.0
# 5                                          0.5
# 6                                          0.6
# 7                                            N
# 8                                          0.3
# 9                                          0.3
#
#   Percent; ANCESTRY - Total population - Danish  ...   \
# 0                                           1.0  ...
# 1                                           0.2  ...
# 2                                           0.4  ...
# 3                                           0.2  ...
# 4                                           0.2  ...
# 5                                           1.1  ...
# 6                                           0.5  ...
# 7                                             N  ...
# 8                                           0.4  ...
# 9                                           0.1  ...
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1940 to 1949  \
# 0                                               27.4
# 1                                                9.5
# 2                                               25.6
# 3                                               19.4
# 4                                                4.8
# 5                                               12.1
# 6                                               32.3
# 7                                                3.7
# 8                                                3.0
# 9                                                6.4
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1950 to 1959  \
# 0                                                4.8
# 1                                                7.0
# 2                                                5.5
# 3                                                8.0
# 4                                                4.9
# 5                                                5.8
# 6                                                6.0
# 7                                                6.6
# 8                                                4.0
# 9                                                7.7
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1960 to 1969  \
# 0                                                6.7
# 1                                               19.8
# 2                                               12.7
# 3                                               16.5
# 4                                               14.1
# 5                                               10.9
# 6                                               12.4
# 7                                                9.8
# 8                                               10.7
# 9                                               11.8
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1970 to 1979  \
# 0                                               13.3
# 1                                               11.8
# 2                                                8.0
# 3                                               12.4
# 4                                               11.4
# 5                                                9.9
# 6                                               10.0
# 7                                               14.3
# 8                                               10.2
# 9                                               14.6
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1980 to 1989  \
# 0                                               20.1
# 1                                               15.5
# 2                                               14.9
# 3                                               14.4
# 4                                               18.7
# 5                                               26.0
# 6                                               12.9
# 7                                               19.1
# 8                                               20.7
# 9                                               20.7
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 1990 to 1999  \
# 0                                               12.7
# 1                                               16.8
# 2                                                9.1
# 3                                                8.6
# 4                                               17.0
# 5                                                9.2
# 6                                               11.0
# 7                                               15.0
# 8                                               17.2
# 9                                               16.4
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 2000 to 2009  \
# 0                                                9.6
# 1                                                9.6
# 2                                               13.8
# 3                                               11.7
# 4                                               17.0
# 5                                               12.6
# 6                                                9.1
# 7                                               18.2
# 8                                               19.0
# 9                                               12.3
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 2010 to 2013  \
# 0                                                3.6
# 1                                                6.5
# 2                                                8.2
# 3                                                6.7
# 4                                               10.0
# 5                                                7.9
# 6                                                4.5
# 7                                                8.6
# 8                                               10.3
# 9                                                7.0
#
#   Percent; YEAR STRUCTURE BUILT - Total housing units - Built 2014 or later  \
# 0                                                1.9
# 1                                                3.4
# 2                                                2.2
# 3                                                2.2
# 4                                                2.2
# 5                                                5.7
# 6                                                1.8
# 7                                                4.8
# 8                                                5.0
# 9                                                3.2
#
#    year
# 0  2007
# 1  2007
# 2  2007
# 3  2007
# 4  2007
# 5  2007
# 6  2007
# 7  2007
# 8  2007
# 9  2007
#
# [10 rows x 524 columns]

# %%
##saving the ACS df
dem_df.to_csv('data/derived/allDem_df.csv', index=False)

# %% [markdown]
# # Load and merge with crime data

# %%
# load crime data
all_year_dfs = pd.read_csv('data/derived/AC209_RawDump-2.csv.gz')
print(all_year_dfs.shape)
all_year_dfs.head()

# %%
# Filter crime data
norm_rows = all_year_dfs['Counties/principal cities'] == 'Rate per 100,000 inhabitants'
all_year_msa_norm = all_year_dfs[norm_rows]
all_year_msa_norm.head()

# %%
# merge crime and dem
#all_year_msa_norm.merge(dem_df, right_on=['MSA', 'year'], left_on=['msa_label', 'year'])

#line above won't work because msa_label in crime df has 'M.S.A.' suffix on every entry, 
 #so won't match up with demographic df

# %%
all_year_msa_norm.loc[:, 'msa_label_strip'] = all_year_msa_norm['msa_label'].str.replace(' M.S.A.[\d\,\ ]+$', '')
# all_year_msa_norm[['msa_label_strip', 'year']].head()

# %%
dem_df[['MSA', 'year']].head()

# %% [markdown]
# Some the MSA labels contain a number after the state abbreviation: e.g. 'Akron, OH2'. This is fixed with a regex replacement like the M.S.A. above.

# %%
#some the MSA labels contain a number after the state abbreviation: e.g. 'Akron, OH2'. NEED TO FIX THIS FOR THE MERGE!
all_year_msa_norm.loc[:, 'msa_label_strip'] = all_year_msa_norm['msa_label_strip'].str.replace(r'[\d\,\ ]+$', '').str.strip()
all_year_msa_norm['msa_label_strip'].head(15)

# %%
all_year_msa_norm[['msa_label_strip', 'year']].head()

# %%
all_year_msa_norm['msa_label_strip'] == 'Abilene, TX'
all_year_msa_norm[['msa_label_strip', 'year']].dtypes

# %%
dem_df.loc[:, 'MSA'] = dem_df['MSA'].str.strip()

# %%
dem_df[['MSA', 'year']].dtypes

# %%
dem_df_merged = pd.merge(left=all_year_msa_norm, left_on=['msa_label_strip', 'year'],
                         right=dem_df, right_on=['MSA', 'year'], how='inner')
dem_df_merged.head(10)

# %%
dem_df_merged.shape

# %%
dem_df_merged.head(10)

# %%
dem_df_merged.to_csv('data/derived/crime_ACS_merged.csv', index=False)
